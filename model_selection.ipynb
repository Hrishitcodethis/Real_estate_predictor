# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
pip show numpy
# Out:
# Name: numpy
# Version: 1.23.5
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages
# Requires:
# Required-by: astropy, bokeh, Bottleneck, category-encoders, contourpy, datashader, datashape, gensim, h5py, holoviews, hvplot, imagecodecs, ImageHash, imageio, imbalanced-learn, matplotlib, mlxtend, numba, numexpr, opencv-python, opt-einsum, pandas, patsy, phik, pyerfa, PyWavelets, scikit-image, scikit-learn, scipy, seaborn, shap, statsmodels, tables, tensorboard, tensorflow-macos, tifffile, transformers, visions, wordcloud, xarray, xgboost, ydata-profiling
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('gurgaon_properties_post_feature_selection_2.csv')

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  \
# 0          flat   sector 63   7.90      4.0       4.0      3+
# 1          flat  sector 63a   3.70      3.0       3.0      3+
# 2          flat     manesar   1.20      3.0       3.0      3+
# 3         house   sector 33  11.50      5.0       6.0      3+
# 4          flat  sector 67a   1.85      3.0       4.0       3
#
#         agePossession  built_up_area  servant room  store room  \
# 0  Under Construction         3950.0           0.0         0.0
# 1  Under Construction         2667.0           0.0         0.0
# 2      Moderately Old         2944.0           1.0         0.0
# 3      Relatively New         4680.0           1.0         0.0
# 4        New Property         1941.0           0.0         1.0
#
#    furnishing_type luxury_category floor_category
# 0              1.0          Medium     High Floor
# 1              1.0          Medium      Low Floor
# 2              1.0             Low      Mid Floor
# 3              1.0          Medium      Mid Floor
# 4              0.0            High      Mid Floor

# %%
df.shape
# Out:
# (3554, 13)

# %%
df['furnishing_type'].value_counts()
# Out:
# 1.0    2354
# 0.0    1015
# 2.0     185
# Name: furnishing_type, dtype: int64

# %%
# 0 -> unfurnished
# 1 -> semifurnished
# 2 -> furnished
df['furnishing_type'] = df['furnishing_type'].replace({0.0:'unfurnished',1.0:'semifurnished',2.0:'furnished'})

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  \
# 0          flat   sector 63   7.90      4.0       4.0      3+
# 1          flat  sector 63a   3.70      3.0       3.0      3+
# 2          flat     manesar   1.20      3.0       3.0      3+
# 3         house   sector 33  11.50      5.0       6.0      3+
# 4          flat  sector 67a   1.85      3.0       4.0       3
#
#         agePossession  built_up_area  servant room  store room  \
# 0  Under Construction         3950.0           0.0         0.0
# 1  Under Construction         2667.0           0.0         0.0
# 2      Moderately Old         2944.0           1.0         0.0
# 3      Relatively New         4680.0           1.0         0.0
# 4        New Property         1941.0           0.0         1.0
#
#   furnishing_type luxury_category floor_category
# 0   semifurnished          Medium     High Floor
# 1   semifurnished          Medium      Low Floor
# 2   semifurnished             Low      Mid Floor
# 3   semifurnished          Medium      Mid Floor
# 4     unfurnished            High      Mid Floor

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %% [markdown]
# ### Ordinal Encoding

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.7198670562402387, 0.04206605218811255)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %% [markdown]
# np.expm1 is used when models have been trained on log-transformed target variables

# %%
y_pred = pipeline.predict(X_test)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 1.4678206264894795

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_output
# Out:
# [['linear_reg', 0.7198670562402387, 0.9645315534589922],
#  ['svr', 0.7555934841035177, 0.8883675551661968],
#  ['ridge', 0.7198709241512696, 0.9645938075585608],
#  ['LASSO', 0.05710877167975701, 1.5281147599599396],
#  ['decision tree', 0.7869608021288085, 0.7280662210340364],
#  ['random forest', 0.8862221631484897, 0.5282819297088933],
#  ['extra trees', 0.8707839827711125, 0.5840376492419613],
#  ['gradient boosting', 0.8766178503102126, 0.5477488897254736],
#  ['adaboost', 0.7554752470196019, 0.8500610772274468],
#  ['mlp', 0.8027213149185425, 0.732029743289345],
#  ['xgboost', 0.8922606189954652, 0.4776694657287853]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.892261  0.477669
# 5       random forest  0.886222  0.528282
# 7   gradient boosting  0.876618  0.547749
# 6         extra trees  0.870784  0.584038
# 4       decision tree  0.786961  0.728066
# 9                 mlp  0.802721  0.732030
# 8            adaboost  0.755475  0.850061
# 1                 svr  0.755593  0.888368
# 0          linear_reg  0.719867  0.964532
# 2               ridge  0.719871  0.964594
# 3               LASSO  0.057109  1.528115

# %% [markdown]
# ### OneHotEncoding

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',handle_unknown='ignore'),['sector','agePossession','furnishing_type'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
# Out:
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores.mean(),scores.std()
# Out:
# (0.8487769415264432, 0.023755948813277097)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sector', 'agePossession',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.6826246664623207

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))
# Out:
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.899629  0.472707
# 5       random forest  0.894140  0.476531
# 6         extra trees  0.895871  0.494876
# 7   gradient boosting  0.878599  0.538160
# 9                 mlp  0.869488  0.573779
# 4       decision tree  0.803055  0.660062
# 0          linear_reg  0.848777  0.682625
# 2               ridge  0.848774  0.684281
# 8            adaboost  0.754393  0.828849
# 1                 svr  0.760422  0.873663
# 3               LASSO  0.057109  1.528115

# %% [markdown]
# ### Target Encoder

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (2.6.3)
# Requirement already satisfied: patsy>=0.5.1 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: pandas>=1.0.5 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: numpy>=1.14.0 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from category_encoders) (0.13.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from category_encoders) (1.3.2)
# Requirement already satisfied: scipy>=1.0.0 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from category_encoders) (1.10.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from pandas>=1.0.5->category_encoders) (2022.7)
# Requirement already satisfied: six in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from statsmodels>=0.9.0->category_encoders) (22.0)

# %%
import category_encoders as ce

columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False,handle_unknown='ignore'),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.8199622664890187, 0.02506445202641817)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 5       random forest  0.903227  0.459209
# 10            xgboost  0.902188  0.460126
# 6         extra trees  0.901631  0.472939
# 7   gradient boosting  0.890931  0.516251
# 9                 mlp  0.846075  0.614066
# 8            adaboost  0.821527  0.714282
# 4       decision tree  0.826605  0.721176
# 0          linear_reg  0.819962  0.756369
# 2               ridge  0.819981  0.756486
# 1                 svr  0.774124  0.860835
# 3               LASSO  0.057109  1.528115

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'regressor__n_estimators': [50, 100, 200, 300],
    'regressor__max_depth': [None, 10, 20, 30],
    'regressor__max_samples':[0.1, 0.25, 0.5, 1.0],
    'regressor__max_features': ['sqrt']
}

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False,handle_unknown='ignore'),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedRoom',
#                                                                           'bathroom',
#                                                                           'built_up_area',
#                                                                           'servant '
#                                                                           'room',
#                                                                           'store '
#                                                                           'room']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['property_type',
#                                                                           's...
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['agePossession']),
#                                                                         ('target_enc',
#                                                                          TargetEncoder(),
#                                                                          ['sector'])])),
#                                        ('regressor', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 30],
#                          'regressor__max_features': ['sqrt'],
#                          'regressor__max_samples': [0.1, 0.25, 0.5, 1.0],
#                          'regressor__n_estimators': [50, 100, 200, 300]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': 30,
#  'regressor__max_features': 'sqrt',
#  'regressor__max_samples': 1.0,
#  'regressor__n_estimators': 300}

# %%
search.best_score_
# Out:
# 0.9021515698640797

# %%
final_pipe.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['agePossession']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['sector'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=30, max_features='sqrt',
#                                        max_samples=1.0, n_estimators=300))])

# %% [markdown]
# ### Exporting the model

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False,handle_unknown='ignore'),['sector','agePossession'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=500))
])

# %%
pipeline.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['sector',
#                                                    'agePossession'])])),
#                 ('regressor', RandomForestRegressor(n_estimators=500))])

# %%
import pickle

with open('pipeline2.pkl', 'wb') as file:
    pickle.dump(pipeline, file)

# %%
with open('df2.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
X
# Out:
#      property_type      sector  bedRoom  bathroom balcony       agePossession  \
# 0             flat   sector 63      4.0       4.0      3+  Under Construction
# 1             flat  sector 63a      3.0       3.0      3+  Under Construction
# 2             flat     manesar      3.0       3.0      3+      Moderately Old
# 3            house   sector 33      5.0       6.0      3+      Relatively New
# 4             flat  sector 67a      3.0       4.0       3        New Property
# ...            ...         ...      ...       ...     ...                 ...
# 3549         house   sector 72      4.0       5.0      3+      Relatively New
# 3550          flat   sector 28      2.0       2.0       2      Moderately Old
# 3551          flat   sector 28      3.0       4.0       3        Old Property
# 3552          flat   sector 79      2.0       2.0      3+        New Property
# 3553          flat   sector 56      3.0       3.0       2        Old Property
#
#       built_up_area  servant room  store room furnishing_type luxury_category  \
# 0            3950.0           0.0         0.0   semifurnished          Medium
# 1            2667.0           0.0         0.0   semifurnished          Medium
# 2            2944.0           1.0         0.0   semifurnished             Low
# 3            4680.0           1.0         0.0   semifurnished          Medium
# 4            1941.0           0.0         1.0     unfurnished            High
# ...             ...           ...         ...             ...             ...
# 3549         7000.0           0.0         0.0     unfurnished             Low
# 3550         1109.0           0.0         0.0   semifurnished             Low
# 3551         3133.0           1.0         1.0   semifurnished             Low
# 3552         1223.0           0.0         0.0     unfurnished             Low
# 3553         1920.0           1.0         0.0     unfurnished          Medium
#
#      floor_category
# 0        High Floor
# 1         Low Floor
# 2         Mid Floor
# 3         Mid Floor
# 4         Mid Floor
# ...             ...
# 3549      Mid Floor
# 3550      Low Floor
# 3551      Mid Floor
# 3552      Mid Floor
# 3553      Mid Floor
#
# [3554 rows x 12 columns]

# %% [markdown]
# ### Trying out the predictions

# %%
X.columns
# Out:
# Index(['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
#        'agePossession', 'built_up_area', 'servant room', 'store room',
#        'furnishing_type', 'luxury_category', 'floor_category'],
#       dtype='object')

# %%
X.iloc[0].values
# Out:
# array(['flat', 'sector 63', 4.0, 4.0, '3+', 'Under Construction', 3950.0,
#        0.0, 0.0, 'semifurnished', 'Medium', 'High Floor'], dtype=object)

# %%
data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df
# Out:
#   property_type      sector  bedRoom  bathroom balcony agePossession  \
# 0         house  sector 102        4         3      3+  New Property
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0           2750             0           0     unfurnished             Low
#
#   floor_category
# 0      Low Floor

# %%
np.expm1(pipeline.predict(one_df))
# Out:
# array([2.69086743])

# %%
X.dtypes
# Out:
# property_type       object
# sector              object
# bedRoom            float64
# bathroom           float64
# balcony             object
# agePossession       object
# built_up_area      float64
# servant room       float64
# store room         float64
# furnishing_type     object
# luxury_category     object
# floor_category      object
# dtype: object

# %%
X.isnull().sum()
# Out:
# property_type      0
# sector             0
# bedRoom            0
# bathroom           0
# balcony            0
# agePossession      0
# built_up_area      0
# servant room       0
# store room         0
# furnishing_type    0
# luxury_category    0
# floor_category     0
# dtype: int64
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.880 total time=   0.1s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.884 total time=   0.1s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.894 total time=   0.1s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.847 total time=   0.1s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.862 total time=   0.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.865 total time=   0.1s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.860 total time=   0.1s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.867 total time=   0.1s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.886 total time=   0.3s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.889 total time=   0.3s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.888 total time=   0.3s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.885 total time=   0.3s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.873 total time=   0.3s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.886 total time=   0.4s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=300;, score=0.895 total time=   0.5s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=300;, score=0.896 total time=   0.5s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.859 total time=   0.1s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.861 total time=   0.1s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.877 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.885 total time=   0.1s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.893 total time=   0.1s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.846 total time=   0.1s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.866 total time=   0.1s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.864 total time=   0.1s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.875 total time=   0.1s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.866 total time=   0.1s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.852 total time=   0.1s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.863 total time=   0.1s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.879 total time=   0.2s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.879 total time=   0.2s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.892 total time=   0.2s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.850 total time=   0.2s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.885 total time=   0.3s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.880 total time=   0.3s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=300;, score=0.883 total time=   0.5s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=300;, score=0.886 total time=   0.4s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.886 total time=   0.1s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.890 total time=   0.1s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.898 total time=   0.2s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.896 total time=   0.2s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.897 total time=   0.4s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.895 total time=   0.3s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.898 total time=   0.5s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.896 total time=   0.5s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.900 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.897 total time=   0.1s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.895 total time=   0.1s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.883 total time=   0.1s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.895 total time=   0.2s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.886 total time=   0.2s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.881 total time=   0.5s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.889 total time=   0.6s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.1, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.895 total time=   0.3s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.849 total time=   0.3s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.874 total time=   0.3s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.871 total time=   0.3s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.873 total time=   0.3s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.871 total time=   0.3s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.858 total time=   0.3s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.866 total time=   0.3s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.888 total time=   0.2s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.896 total time=   0.2s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.907 total time=   0.3s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.904 total time=   0.3s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.920 total time=   0.3s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.881 total time=   0.4s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.902 total time=   0.4s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.896 total time=   0.3s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.25, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=0.5, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=auto, regressor__max_samples=1.0, regressor__n_estimators=300;, score=nan total time=   0.0s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.849 total time=   0.1s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.864 total time=   0.1s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.879 total time=   0.1s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.883 total time=   0.1s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.881 total time=   0.2s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.887 total time=   0.2s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.893 total time=   0.2s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.847 total time=   0.2s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.872 total time=   0.3s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.869 total time=   0.3s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.861 total time=   0.3s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.866 total time=   0.3s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.880 total time=   0.1s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.893 total time=   0.1s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.902 total time=   0.2s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.899 total time=   0.3s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.916 total time=   0.3s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.877 total time=   0.3s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.893 total time=   0.2s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.896 total time=   0.3s
# [CV 5/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.895 total time=   0.7s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.882 total time=   0.8s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.898 total time=   0.2s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.901 total time=   0.2s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.901 total time=   0.4s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.923 total time=   0.7s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.895 total time=   0.7s
# [CV 6/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.903 total time=   1.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.867 total time=   0.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.871 total time=   0.1s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.882 total time=   0.2s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.885 total time=   0.2s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.858 total time=   0.3s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.865 total time=   0.3s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.873 total time=   0.3s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.885 total time=   0.4s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.891 total time=   0.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.895 total time=   0.1s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.902 total time=   0.2s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.902 total time=   0.2s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.896 total time=   0.4s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.899 total time=   0.5s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.882 total time=   0.7s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.893 total time=   0.7s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.911 total time=   1.0s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.908 total time=   1.0s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.871 total time=   0.2s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.870 total time=   0.2s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.857 total time=   0.2s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=300;, score=0.866 total time=   0.3s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.882 total time=   0.1s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.880 total time=   0.1s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=300;, score=0.884 total time=   0.4s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=300;, score=0.886 total time=   0.4s
# ...
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.889 total time=   0.5s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.918 total time=   0.2s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.879 total time=   0.2s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.887 total time=   0.2s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.896 total time=   0.2s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.908 total time=   0.7s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.908 total time=   0.7s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.902 total time=   0.9s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.897 total time=   0.7s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.894 total time=   0.9s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=50;, score=0.866 total time=   0.1s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=100;, score=0.896 total time=   0.1s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.859 total time=   0.2s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.865 total time=   0.3s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.907 total time=   0.1s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.860 total time=   0.1s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.908 total time=   0.2s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.865 total time=   0.2s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.886 total time=   0.3s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.889 total time=   0.3s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.904 total time=   0.1s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.897 total time=   0.1s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.895 total time=   0.1s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.890 total time=   0.1s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.882 total time=   0.2s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.894 total time=   0.3s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.897 total time=   0.7s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.898 total time=   0.7s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.902 total time=   0.3s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.893 total time=   0.4s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.922 total time=   1.0s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.884 total time=   0.9s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.859 total time=   0.2s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.865 total time=   0.2s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.888 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.891 total time=   0.1s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.904 total time=   0.1s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.860 total time=   0.1s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.887 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.893 total time=   0.1s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.882 total time=   0.2s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.882 total time=   0.2s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.896 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.891 total time=   0.1s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.890 total time=   0.1s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.888 total time=   0.1s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.878 total time=   0.2s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.881 total time=   0.2s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.889 total time=   0.5s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.892 total time=   0.5s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.893 total time=   0.2s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.887 total time=   0.2s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.901 total time=   0.7s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.902 total time=   0.7s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.857 total time=   0.2s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.865 total time=   0.2s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.891 total time=   0.1s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.896 total time=   0.1s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.883 total time=   0.1s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.882 total time=   0.1s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.909 total time=   0.2s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.866 total time=   0.2s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.874 total time=   0.3s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.886 total time=   0.3s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.894 total time=   0.1s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.899 total time=   0.1s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.905 total time=   0.2s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.897 total time=   0.5s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.899 total time=   0.5s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.920 total time=   0.2s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.881 total time=   0.2s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.886 total time=   0.2s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.892 total time=   0.2s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.889 total time=   0.3s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.900 total time=   0.3s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.906 total time=   1.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.903 total time=   1.0s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.863 total time=   0.2s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.1, regressor__n_estimators=200;, score=0.866 total time=   0.2s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.892 total time=   0.1s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.898 total time=   0.1s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.909 total time=   0.1s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.872 total time=   0.1s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.897 total time=   0.2s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.892 total time=   0.2s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.889 total time=   0.3s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.887 total time=   0.3s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.914 total time=   0.1s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.869 total time=   0.1s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.877 total time=   0.1s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.893 total time=   0.1s
# [CV 1/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.904 total time=   0.4s
# [CV 2/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.901 total time=   0.5s
# [CV 7/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.896 total time=   0.7s
# [CV 8/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=300;, score=0.890 total time=   0.7s
# [CV 3/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.921 total time=   0.7s
# [CV 4/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.885 total time=   0.7s
# [CV 9/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.891 total time=   0.8s
# [CV 10/10] END regressor__max_depth=30, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=300;, score=0.899 total time=   0.7s

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.3.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: category-encoders, imbalanced-learn, mlxtend, shap
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (1.3.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-macosx_12_0_arm64.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 4.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from scikit-learn) (2.2.0)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages (from scikit-learn) (1.10.0)
# Installing collected packages: joblib, scikit-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# Successfully installed joblib-1.3.2 scikit-learn-1.4.0

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.4.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /Users/hrishityelchuri/anaconda3/lib/python3.10/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: category-encoders, imbalanced-learn, mlxtend, shap
# Note: you may need to restart the kernel to use updated packages.
